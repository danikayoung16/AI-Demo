# %% [markdown]
# <a href="https://colab.research.google.com/github/danikayoung16/AI-Demo/blob/main/AI_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
import os

def main():
    api_key = os.environ.get("GENAI_API_KEY", " ")
    client = genai.Client(api_key=api_key)
    chat = client.chats.create(model="gemini-2.0-flash")

    # Initialize difficulty (1 = Easy, 5 = Hard)
    difficulty_level = 1

    print("\nWelcome to the AI-Enhanced Coding Assistant!")
    print("This session focuses on Lesson 3.1: Stacks (LIFO).")
    print("We'll give you one-line stack-related coding challenges and provide real-time AI feedback on your code.")
    print("Commands: 'skip' = new challenge, 'quit'/'exit' = end session.\n")

    while True:
        # Generate a one-line challenge without revealing solution code.
        challenge_prompt = (
            "You are an AI teaching assistant for a kid-friendly Python curriculum.\n"
            "Focus on Lesson 3.1: Stacks (LIFO). Generate ONE coding challenge that requires the student to write a single line "
            "of code to perform a stack operation (using a Python list with append or pop) without providing any sample solution code.\n\n"
            f"Difficulty level: {difficulty_level}\n\n"
            "Example ideas: 'Push an item onto the stack' or 'Pop an item from the stack'."
        )

        input("Press Enter when you're ready to view the challenge...")  # Pause before showing instructions
        print(f"\n--- Challenge (Difficulty = {difficulty_level}) ---")
        challenge_stream = chat.send_message_stream(challenge_prompt)
        for chunk in challenge_stream:
            print(chunk.text, end="")
        print("\n--- End of Challenge ---\n")

        # Student attempts the challenge.
        while True:
            student_code = input("Paste your solution code (or type 'skip' to try a new challenge):\n")
            if student_code.strip().lower() in ["quit", "exit"]:
                print("Thanks for using the AI Coding Assistant. Goodbye!")
                print_full_history(chat)
                return
            if student_code.strip().lower() == "skip":
                print("Skipping this challenge. We'll move on to a new one.\n")
                break  # Request a fresh challenge

            # Provide AI feedback on the student's code after submission.
            feedback_prompt = (
                "You are an AI teaching assistant for a kid-friendly Python curriculum.\n"
                "We're focusing on Lesson 3.1: Stacks (LIFO). The student submitted the following one-line code:\n\n"
                f"{student_code}\n\n"
                "Please provide gentle feedback by:\n"
                "1. Identifying any logic or syntax errors.\n"
                "2. Offering a helpful debugging tip if needed.\n"
                f"3. Suggesting a small next step based on difficulty level {difficulty_level}.\n\n"
                "Keep your language friendly and simple."
            )

            print("\n--- AI Feedback (Streaming) ---")
            try:
                feedback_response = chat.send_message_stream(feedback_prompt)
                for chunk in feedback_response:
                    print(chunk.text, end="")
            except Exception as e:
                print("Error while generating feedback:", e)
            print("\n--- End of Feedback ---\n")

            # Ask if the student wants to try again or move on
            retry = input("Type 'again' to try this challenge again, or 'new' to move on: ").strip().lower()
            if retry != "again":
                print("\nMoving on to a new challenge...\n")
                break

        # Adjust difficulty based on student feedback.
        user_assessment = input("Was the challenge 'too easy', 'too hard', or 'just right'? ").strip().lower()
        if user_assessment == "too easy":
            difficulty_level = min(difficulty_level + 1, 5)
            print(f"Difficulty increased to {difficulty_level}.\n")
        elif user_assessment == "too hard":
            difficulty_level = max(difficulty_level - 1, 1)
            print(f"Difficulty decreased to {difficulty_level}.\n")
        else:
            print("Difficulty remains the same.\n")

    print_full_history(chat)

def print_full_history(chat):
    """Utility function to print the entire conversation history."""
    print("--- Full Conversation History ---")
    for msg in chat.get_history():
        text = msg.parts[0].text if msg.parts and hasattr(msg.parts[0], 'text') else "<no text>"
        print(f"role - {msg.role}:", text)

if __name__ == "__main__":
    main()
# Out:
# Welcome to the AI-Enhanced Coding Assistant!
# This session focuses on Lesson 3.1: Stacks (LIFO).
# We'll give you one-line stack-related coding challenges and provide real-time AI feedback on your code.
# Commands: 'skip' = new challenge, 'quit'/'exit' = end session.
#
# Press Enter when you're ready to view the challenge...
#
# --- Challenge (Difficulty = 1) ---
# Okay, class! Let's see if you're ready to be super stack stars!
#
# **Coding Challenge:**
#
# Imagine you have a stack of pancakes, represented by the list `pancakes = ['blueberry', 'chocolate chip', 'banana']`. You just ate the top pancake.
#
# Write a single line of Python code to remove (pop) the top pancake from the `pancakes` list.
#
# --- End of Challenge ---
#
# Paste your solution code (or type 'skip' to try a new challenge):
# pancake.pop()
#
# --- AI Feedback (Streaming) ---
# Hey there! That's a great first try! I see you're trying to use the `pop()` method, which is exactly what we need to do.
#
# Here's a tiny tweak: Remember, `pop()` is a method that belongs to the *list* named `pancakes`. You're calling `pop()` on something called `pancake`, which isn't the name of your list.
#
# **Debugging Tip:** Double-check that you're using the correct name of the list where the pancakes are stored!
#
# **Next Step:** Try calling `pop()` on the correct list name! I know you can do it!
#
# --- End of Feedback ---
#
# Type 'again' to try this challenge again, or 'new' to move on: again
# Paste your solution code (or type 'skip' to try a new challenge):
# pancakes.pop()
#
# --- AI Feedback (Streaming) ---
# Awesome job! That's exactly right! `pancakes.pop()` removes the top pancake from the list. You've nailed the single-line stack pop!
#
# **Next Step:** Now that you can pop a pancake, how about we see *which* pancake you popped?  After the `pancakes.pop()` line, add another line that prints the `pancakes` list. That way, you can see what's left in the stack after you ate one!
#
# --- End of Feedback ---
#
# Type 'again' to try this challenge again, or 'new' to move on: new
#
# Moving on to a new challenge...
#
# Was the challenge 'too easy', 'too hard', or 'just right'? just right
# Difficulty remains the same.
#
# Press Enter when you're ready to view the challenge...
#
# --- Challenge (Difficulty = 1) ---
# Okay, here's another coding challenge!
#
# **Coding Challenge:**
#
# You're building a tower of blocks! You have a list called `tower` which currently holds some blocks: `tower = ['red', 'blue', 'green']`. You just found a shiny new 'yellow' block!
#
# Write a single line of Python code to add (push) the 'yellow' block to the top of the `tower`.
#
# --- End of Challenge ---
#
# Paste your solution code (or type 'skip' to try a new challenge):
# tower.append("yellow")
#
# --- AI Feedback (Streaming) ---
# Fantastic
# --- End of Feedback ---
#
# Type 'again' to try this challenge again, or 'new' to move on: new
#
# Moving on to a new challenge...
#
# Was the challenge 'too easy', 'too hard', or 'just right'? too easy
# Difficulty increased to 2.
#
# Press Enter when you're ready to view the challenge...
#
# --- Challenge (Difficulty = 2) ---
# Alright, rising stack stars, let's level up!
#
# **Coding Challenge:**
#
# You have a playlist represented by a list called `song_stack`. Songs are added and removed in Last-In, First-Out (LIFO) order (like a stack!).
#
# ```python
# song_stack = ['Song A', 'Song B', 'Song C']
# ```
#
# You want to remove the last song added to the playlist (the top of the stack) and store it in a variable called `last_played`.
#
# Write a single line of Python code that both *removes* the last song from `song_stack` AND *assigns* it to the variable `last_played`.
#
# --- End of Challenge ---
#
# Paste your solution code (or type 'skip' to try a new challenge):
# last_played = song_stack.pop()
#
# --- AI Feedback (Streaming) ---
# Fantastic
# --- End of Feedback ---
#
# Type 'again' to try this challenge again, or 'new' to move on: new
#
# Moving on to a new challenge...
#
# Was the challenge 'too easy', 'too hard', or 'just right'? just right
# Difficulty remains the same.
#
# Press Enter when you're ready to view the challenge...
#
# --- Challenge (Difficulty = 2) ---
# Okay, future Python pros, let's see your stack skills!
#
# **Coding Challenge:**
#
# You're simulating undo functionality in a simple text editor. You have a list called `undo_stack` which stores the previous states of the text.
#
# ```python
# undo_stack = ["Version 1: Initial text", "Version 2: Added a sentence", "Version 3: Corrected a typo"]
# ```
#
# Before adding a new version ("Version 4: Added an image"), you want to make sure the stack doesn't get too long. If the stack already has 3 or more items, you need to remove the *oldest* version (the *bottom* of the stack).
#
# Write a single line of Python code that removes the oldest version from the `undo_stack` *only if* the `undo_stack` has 3 or more items in it. (Hint: Think about how you check the length of a list and how to remove from the beginning instead of the end).
#
# --- End of Challenge ---
#
# Paste your solution code (or type 'skip' to try a new challenge):
# skip
# Skipping this challenge. We'll move on to a new one.
#
# Was the challenge 'too easy', 'too hard', or 'just right'? too easy
# Difficulty increased to 3.
#
# Press Enter when you're ready to view the challenge...
#
# --- Challenge (Difficulty = 3) ---
# Alright, Python Pioneers! Time for a real stack challenge!
#
# **Coding Challenge:**
#
# You're helping a librarian organize books. They have a `book_stack` list representing the books currently being placed on a shelf. To make sure the shelf doesn't get overloaded, there's a `max_books` limit.
#
# ```python
# book_stack = ['Book A', 'Book B']
# max_books = 5
# new_book = 'Book C'
# ```
#
# Write a single line of Python code that *conditionally* adds the `new_book` to the `book_stack` **only if** adding the new book wouldn't exceed the `max_books` limit. The line should do *nothing* if the stack is already full. You need to use the `append` method, but only when there's space!
#
# --- End of Challenge ---
#
# Paste your solution code (or type 'skip' to try a new challenge):
# len(book_stack) < max_books and book_stack.append(new_book)
#
# --- AI Feedback (Streaming) ---
# Fantastic attempt! I can see you're combining the condition and the `append` in a single line, which is exactly what I was hoping for!
#
# Here's a little tweak: While your code *checks* if there's enough space using `len(book_stack) < max_books`, the `and` operator in Python works a bit differently than how we might think of it in regular English. It evaluates the first part (the `len(book_stack) < max_books` check), and if that's true, it then *returns* the value of the second part. The `append` method itself doesn't return a 'true' or 'false' value; it actually returns `None`. So, your code is checking the length, and if there's space, it's appending the book, but the overall result of the line isn't actually doing anything with the return value of `append` (which is `None`). We need to make it explicitly add the book *if* there's space using an `if` statement.
#
# **Debugging Tip:** Sometimes, breaking a problem down into smaller steps can make it easier to solve. Try writing the `if` statement on its own first, *then* put the `append` inside the `if`.
#
# **Next Step:** Rewrite the line using an `if` statement, all on one line, like this: `if condition: action`. Remember the colon! You're almost there!
#
# --- End of Feedback ---
#
# Type 'again' to try this challenge again, or 'new' to move on: if Len(book_stack) < max_books: book_stack.append(new_book)
#
# Moving on to a new challenge...
